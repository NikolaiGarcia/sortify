# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
SPOTIPY_CLIENT_ID='4250de878e2b4756a4a3830dfbcd29c6'
SPOTIPY_CLIENT_SECRET='e5f42ce007eb4ff7a6fe81251f6ae0a4'
SPOTIPY_REDIRECT_URI='https://localhost:8888/callback'

# %%
scope = ["user-library-read","user-library-modify","playlist-modify-private"]

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID,client_secret=SPOTIPY_CLIENT_SECRET,redirect_uri=SPOTIPY_REDIRECT_URI,scope=scope))

result = sp.current_user_saved_tracks()

# %%
track_0['track']['href']
# Out:
# 'https://api.spotify.com/v1/tracks/19aYH2zhbnTNx4plfenrIk'

# %%
df = pd.read_csv("datasets/spotify_songs.csv")

# %%
df[df['playlist_genre']=='rock']
# Out:
#                      track_id             track_name   track_artist  \
# 11253  3YBZIN3rekqsKxbJc9FZko          Paradise City  Guns N' Roses
# 11254  5tqSUxm3Wpql0dlLMrIAp1    Shadow Of Your Love  Guns N' Roses
# 11255  0bVtevEgtDIeRjCJbK3Lmv  Welcome To The Jungle  Guns N' Roses
# 11256  63HA3dpnOmdDcazJ9sDfrh           It's So Easy  Guns N' Roses
# 11257  2vNw57KPaYDzkyPxXYUORX              Nightrain  Guns N' Roses
# ...                       ...                    ...            ...
# 16199  7ISL3LO8AWP3fKIXunvqTa    Joker And The Thief     Wolfmother
# 16200  3CkjLJYnnyOtGk4Jx4iYS4                  Woman     Wolfmother
# 16201  1lATXTBJDHwawvT1UfxWu3                The Pot           TOOL
# 16202  55mJleti2WfWEFNFcBduhc                 Schism           TOOL
# 16203  1vxu8vMNshg5J8z3oA7QJZ               Parabola           TOOL
#
#        track_popularity          track_album_id          track_album_name  \
# 11253                78  3I9Z1nDCL4E0cP62flcbI5  Appetite For Destruction
# ...

# %%
df.query("track_name in 'Te Amo'")
# Out:
#                      track_id track_name  track_artist  track_popularity  \
# 20965  6GvSHhIxdWaQJbiQyzdOCy     Te Amo  Triple Seven                37
#
#                track_album_id track_album_name track_album_release_date  \
# 20965  0SwG9W9WTQNhAJV8z4LYNU                7               2013-07-31
#
#                             playlist_name             playlist_id  \
# 20965  LATIN FLOW MIX - Música Cristiana🎵  396llvvFOIB9jgPg0kqNDb
#
#       playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 20965          latin     latin hip hop         0.728   0.932    4    -4.141
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 20965     1       0.0569         0.147               0.0     0.287    0.715
#
#          tempo  duration_ms
# 20965  128.005       261148

# %%
result['items'][1]['track']['uri']
# Out:
# 'spotify:track:5nN1jGnCadYk1jYm6oV5zN'

# %%
sp.current_user_playlists()
# Out:
# {'href': 'https://api.spotify.com/v1/users/31mlxgg6h4qr7kmqfcjs4sf72bn4/playlists?offset=0&limit=0',
#  'limit': 0,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 0,
#  'items': []}

# %%
sp.user_playlist_create('31mlxgg6h4qr7kmqfcjs4sf72bn4',name='rock',public=False)
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/77twuxtwlYzfAWdtAfeYVW'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/77twuxtwlYzfAWdtAfeYVW',
#  'id': '77twuxtwlYzfAWdtAfeYVW',
#  'images': [],
#  'primary_color': None,
#  'name': 'rock',
#  'type': 'playlist',
#  'uri': 'spotify:playlist:77twuxtwlYzfAWdtAfeYVW',
#  'owner': {'href': 'https://api.spotify.com/v1/users/31mlxgg6h4qr7kmqfcjs4sf72bn4',
#   'id': '31mlxgg6h4qr7kmqfcjs4sf72bn4',
#   'type': 'user',
#   'uri': 'spotify:user:31mlxgg6h4qr7kmqfcjs4sf72bn4',
#   'display_name': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/user/31mlxgg6h4qr7kmqfcjs4sf72bn4'}},
#  'public': False,
#  'snapshot_id': 'AAAAAd+4cyA9ES+XFYGkn6coMYwCW4/S',
#  'tracks': {'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
# ...

# %%
sp.playlist_add_items(playlist_id='77twuxtwlYzfAWdtAfeYVW',items=['spotify:track:5nN1jGnCadYk1jYm6oV5zN'])
# Out:
# {'snapshot_id': 'AAAAAlFzbYo+w+CIiGmJRPs5izrdSB8W'}

# %%
sp.current_user_saved_tracks_delete(tracks=['spotify:track:5nN1jGnCadYk1jYm6oV5zN'])
